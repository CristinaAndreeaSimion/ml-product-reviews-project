# %% [markdown]
# <a href="https://colab.research.google.com/github/CristinaAndreeaSimion/ml-product-reviews-project/blob/main/notebooks/product_reviews_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *PRODUCT REVIEWS ANALYSIS
#
# **Author: Cristina Simion
